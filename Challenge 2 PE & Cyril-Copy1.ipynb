# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img_ex = cv2.imread('data/gear_images/axes/10045714_zm.jpeg', 1)

# %%
plt.imshow(img_ex, cmap='gray')
img_ex.shape
# Out:
# (400, 210, 3)

# %%
import numpy as np

def ordered_colors(img, log=False):
    if log:
        plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB), cmap='gray')
    return cv2.cvtColor(img, cv2.COLOR_BGR2RGB)


    
def pad(img, log=False):
    h, w = img.shape[:-1]
    padded_image = cv2.copyMakeBorder(img, 
                                   int(np.floor(0.5*(w-h)*(w>=h))), 
                                   int(np.ceil(0.5*(w-h)*(w>=h))), 
                                   int(np.floor(0.5*(h-w)*(w<h))), 
                                   int(np.ceil(0.5*(h-w)*(w<h))),
                                   cv2.BORDER_CONSTANT, 
                                   value=[255,255,255])

    if log:
        plt.imshow(padded_image, cmap='gray')
        print(padded_image.shape)

    return padded_image

def my_reshape(img, log=False):
    resized_image = cv2.resize(img, (128, 128))
    
    if log:
        plt.imshow(resized_image, cmap='gray')
        
    return resized_image

def stretching(img):
    intensity_im = cv2.cvtColor(img, cv2.COLOR_BGR2YUV)
    enhanequalizeHist

from skimage import color, exposure
    
def stretching_file(img, log=False):
    if log:
        plt.imshow(img, cmap='gray')
    img_rescale = exposure.equalize_adapthist(img)
    img_rescale = exposure.rescale_intensity(img_rescale, out_range=(0, 255)).astype(int)
    if log:
        plt.imshow(img_rescale, cmap='gray')
    return img_rescale

# %%
# checking values
my_max = my_reshape(pad(ordered_colors(img_ex, log=True)), log=True).max()
my_min = my_reshape(pad(ordered_colors(img_ex, log=True)), log=True).min()

assert my_max <= 255
assert my_min >= 0

# %%
stretching_file(my_reshape(pad(ordered_colors(img_ex, log=True)), log=True), log=True)
# Out:
# /anaconda/envs/py35/lib/python3.5/site-packages/skimage/util/dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint16
#   .format(dtypeobj_in, dtypeobj_out))
# array([[[252, 252, 252],
#         [252, 252, 252],
#         [252, 252, 252],
#         ...,
#         [252, 252, 252],
#         [252, 252, 252],
#         [252, 252, 252]],
#
#        [[252, 252, 252],
#         [252, 252, 252],
#         [252, 252, 252],
#         ...,
#         [252, 252, 252],
#         [252, 252, 252],
#         [252, 252, 252]],
#
#        [[252, 252, 252],
#         [252, 252, 252],
#         [252, 252, 252],
#         ...,
#         [252, 252, 252],
#         [252, 252, 252],
#         [252, 252, 252]],
#
#        ...,
#
#        [[252, 252, 252],
#         [252, 252, 252],
#         [252, 252, 252],
#         ...,
#         [252, 252, 252],
#         [252, 252, 252],
#         [252, 252, 252]],
#
#        [[252, 252, 252],
#         [252, 252, 252],
#         [252, 252, 252],
#         ...,
#         [252, 252, 252],
#         [252, 252, 252],
#         [252, 252, 252]],
#
#        [[252, 252, 252],
#         [252, 252, 252],
#         [252, 252, 252],
#         ...,
#         [252, 252, 252],
#         [252, 252, 252],
#         [252, 252, 252]]])
